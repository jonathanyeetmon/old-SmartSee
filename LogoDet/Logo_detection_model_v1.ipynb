# %%
pip install opencv-python==4.2.0.34
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install protobuf==3.20

# %%
# Weights will be auto-downloaded
import cv2
from predictor import predictor

image_paths = ['images/sportswear-swoosh-mens-t-shirt-LzncrX.png.jpeg','images/HD1330-RMCFMT0131-01.jpg']

predictions = predictor(image_paths)

# %%
print(predictions)
# Out:
# [[{'box': [261, 1079, 1212, 1505], 'score': 0.6758014559745789, 'label': 'nike'}], [{'box': [524, 298, 998, 733], 'score': 0.808953046798706, 'label': 'adidas'}]]

# %%
import matplotlib.pyplot as plt
import numpy
from PIL import Image
import time

# %%
plt.imshow(numpy.array(Image.open(image_paths[0])))
print(predictions[0][0]['label'])
# Out:
# nike

# %%
plt.imshow(numpy.array(Image.open(image_paths[1])))
print(predictions[1][0]['label'])
# Out:
# adidas

# %%
# !python -v
# Out:
# import _frozen_importlib # frozen
# import _imp # builtin
# import '_thread' # <class '_frozen_importlib.BuiltinImporter'>
# import '_warnings' # <class '_frozen_importlib.BuiltinImporter'>
# import '_weakref' # <class '_frozen_importlib.BuiltinImporter'>
# import '_frozen_importlib_external' # <class '_frozen_importlib.FrozenImporter'>
# import '_io' # <class '_frozen_importlib.BuiltinImporter'>
# import 'marshal' # <class '_frozen_importlib.BuiltinImporter'>
# import 'posix' # <class '_frozen_importlib.BuiltinImporter'>
# import _thread # previously loaded ('_thread')
# import '_thread' # <class '_frozen_importlib.BuiltinImporter'>
# import _weakref # previously loaded ('_weakref')
# import '_weakref' # <class '_frozen_importlib.BuiltinImporter'>
# # installing zipimport hook
# import 'time' # <class '_frozen_importlib.BuiltinImporter'>
# import 'zipimport' # <class '_frozen_importlib.FrozenImporter'>
# # installed zipimport hook
# ...
